# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x = np.linspace(0, 5, 11)

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x * x

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#Funcional
plt.plot(x,y, color='r')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
plt.subplots(nrows=1, ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002C3EB76F348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002C3EB74DAC8>],
#        dtype=object))

# %%
plt.subplot(1, 2,1)
plt.plot(x, y, 'r--')
plt.subplot(1, 2,2)
plt.plot(y, x, 'g*-')

# %%
fig = plt.figure()

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.3,0.3])

axes1.plot(x,y)
axes1.set_xlabel('Eixo X')
axes1.set_title('Titulo')
axes2.plot(y,x)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, 'b--')
ax.plot(x, x**4, 'g--')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# %%
ax[0].plot(x,y,'b')
ax[0].set_title('Titulo')

ax[1].plot(x,y,'b')
ax[1].set_title('Titulo')
fig

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(8,3))

axes.plot(x,y,'r-', label = 'x**2')
axes.plot(y,x,'g--', label = 'x**1/2')
axes.set_title('Titulo')
axes.legend()

# %%
fig.savefig("grafico.png")
